# %%
a=2
print(a)
a=input("enter a value : for a :")
print(a)
# Out:
# 2
# 12

# %%
mentor_name = "prashant"
m = "jyoti"

# %%
2 * "prashant"
# Out:
# 'prashantprashant'

# %%
# print(11%2)
# / divide 
# // floor divide
# % remainder
# Out:
# 1
