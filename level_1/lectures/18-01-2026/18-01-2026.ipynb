# %%
str =  "'hellow prashant   '"
print(str.strip())
# Out:
# 'hellow prashant   '

# %%
for i in str:
    if i != " ":
        print(i, end="")
# Out:
# 'hellowprashant'

# %%
name = "  prashant sonawane   "
print(name.rstrip())
print(name.lstrip())
# Out:
#   prashant sonawane
# prashant sonawane

# %%
a= " 26"
print(type(int(a.strip())))
# Out:
# <class 'int'>

# %%
password = " 12345678"
username = " prashant "
print(password.strip())

if username.strip() == "prashant":
    print("username is correct")
    if password.strip() == "12355678":
        print("password is correct")
    else:
        print("password is incorrect")
else:
    print("username is incorrect")
# Out:
# 12345678
# username is correct
# password is incorrect

# %%
ls = [{"name": "prashant", "age": 26}, {"name": "sonawane", "age": 27}]
print(ls[0]["name"])
# Out:
# prashant

# %%
register = []

append_register = ["prashant", "mob: 1234567890", "email:apash@gmail.com"]
register.append(append_register)
append_register = ["sonawane", "mob: 1234567890", "email:son@gmail.com", "address: pune"]
register.append(append_register)
print(register)
# Out:
# [['prashant', 'mob: 1234567890', 'email:apash@gmail.com'], ['sonawane', 'mob: 1234567890', 'email:son@gmail.com', 'address: pune']]

# %%
register[0]
# Out:
# ['prashant', 'mob: 1234567890', 'email:apash@gmail.com']
